# %% [markdown]
# <a href="https://colab.research.google.com/github/alswjd5991/-11-kaggle-/blob/cooperation/%ED%86%B5%ED%95%A9_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **데이터 로드 및 분리**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 훈련데이터 불러오기
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백팩/train.csv')
train.head()
# Out:
#    id         Brand Material    Size  Compartments Laptop Compartment  \
# 0   0      Jansport  Leather  Medium           7.0                Yes
# 1   1      Jansport   Canvas   Small          10.0                Yes
# 2   2  Under Armour  Leather   Small           2.0                Yes
# 3   3          Nike    Nylon   Small           8.0                Yes
# 4   4        Adidas   Canvas  Medium           1.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)      Price
# 0         No       Tote  Black             11.611723  112.15875
# 1        Yes  Messenger  Green             27.078537   68.88056
# 2         No  Messenger    Red             16.643760   39.17320
# 3         No  Messenger  Green             12.937220   80.60793
# 4        Yes  Messenger  Green             17.749338   86.02312

# %%
# 테스트데이터 불러오기
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백팩/test.csv')
test.head()
# Out:
#        id   Brand Material    Size  Compartments Laptop Compartment  \
# 0  300000    Puma  Leather   Small           2.0                 No
# 1  300001    Nike   Canvas  Medium           7.0                 No
# 2  300002  Adidas   Canvas   Large           9.0                 No
# 3  300003  Adidas    Nylon   Large           1.0                Yes
# 4  300004     NaN    Nylon   Large           2.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)
# 0         No       Tote  Green             20.671147
# 1        Yes   Backpack  Green             13.564105
# 2        Yes  Messenger   Blue             11.809799
# 3         No  Messenger  Green             18.477036
# 4        Yes       Tote  Black              9.907953

# %%
# 타겟 데이터 분리
train_target=train['Price']
train_target.head()
train_input=train.drop('Price',axis=1)
train_input.head()
# Out:
#    id         Brand Material    Size  Compartments Laptop Compartment  \
# 0   0      Jansport  Leather  Medium           7.0                Yes
# 1   1      Jansport   Canvas   Small          10.0                Yes
# 2   2  Under Armour  Leather   Small           2.0                Yes
# 3   3          Nike    Nylon   Small           8.0                Yes
# 4   4        Adidas   Canvas  Medium           1.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)
# 0         No       Tote  Black             11.611723
# 1        Yes  Messenger  Green             27.078537
# 2         No  Messenger    Red             16.643760
# 3         No  Messenger  Green             12.937220
# 4        Yes  Messenger  Green             17.749338

# %%
train_input=train_input.drop('id',axis=1)
test=test.drop('id',axis=1)

# %% [markdown]
# # **데이터 전처리**

# %%
train_input['Waterproof'] = train_input['Waterproof'].map({'Yes': 1, 'No': 0})
test['Waterproof'] = test['Waterproof'].map({'Yes': 1, 'No': 0})

train_input['Laptop Compartment'] = train_input['Laptop Compartment'].map({'Yes': 1, 'No': 0})
test['Laptop Compartment'] = test['Laptop Compartment'].map({'Yes': 1, 'No': 0})

size_mapping = {'Small': 1, 'Medium': 2, 'Large': 3}
train_input['Size'] = train['Size'].map(size_mapping)
test['Size'] = test['Size'].map(size_mapping)

# %%
train_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Brand                 290295 non-null  object
#  1   Material              291653 non-null  object
#  2   Size                  293405 non-null  float64
#  3   Compartments          300000 non-null  float64
#  4   Laptop Compartment    292556 non-null  float64
#  5   Waterproof            292950 non-null  float64
#  6   Style                 292030 non-null  object
#  7   Color                 290050 non-null  object
#  8   Weight Capacity (kg)  299862 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 20.6+ MB

# %%
# 확인용
train_input.head()
# Out:
#           Brand Material  Size  Compartments  Laptop Compartment  Waterproof  \
# 0      Jansport  Leather   2.0           7.0                 1.0         0.0
# 1      Jansport   Canvas   1.0          10.0                 1.0         1.0
# 2  Under Armour  Leather   1.0           2.0                 1.0         0.0
# 3          Nike    Nylon   1.0           8.0                 1.0         0.0
# 4        Adidas   Canvas   2.0           1.0                 1.0         1.0
#
#        Style  Color  Weight Capacity (kg)
# 0       Tote  Black             11.611723
# 1  Messenger  Green             27.078537
# 2  Messenger    Red             16.643760
# 3  Messenger  Green             12.937220
# 4  Messenger  Green             17.749338

# %% [markdown]
# # **결측값 처리**

# %%
train_input.isnull().sum()
# Out:
# Brand                   9705
# Material                8347
# Size                    6595
# Compartments               0
# Laptop Compartment      7444
# Waterproof              7050
# Style                   7970
# Color                   9950
# Weight Capacity (kg)     138
# dtype: int64

# %% [markdown]
# **수치형 변수 결측값 처리**

# %%
#Size
train_input['Size'].mode()
# Out:
# 0    2.0
# Name: Size, dtype: float64

# %%
train_input['Size'].value_counts(normalize=True) * 100
# Out:
# Size
# 2.0    34.732196
# 3.0    33.620081
# 1.0    31.647722
# Name: proportion, dtype: float64

# %%
train_input['Size']=train_input['Size'].fillna(2)
test['Size']=test['Size'].fillna(2)

# %%
#laptop compartment
train_input['Laptop Compartment'].value_counts(normalize=True) * 100
# Out:
# Laptop Compartment
# 1.0    50.705506
# 0.0    49.294494
# Name: proportion, dtype: float64

# %%
train_input['Laptop Compartment']=train_input['Laptop Compartment'].fillna(0)
test['Laptop Compartment']=test['Laptop Compartment'].fillna(0)

# %%
#waterproof
train_input['Waterproof'].value_counts(normalize=True) * 100
# Out:
# Waterproof
# 1.0    50.546851
# 0.0    49.453149
# Name: proportion, dtype: float64

# %%
train_input['Waterproof']=train_input['Waterproof'].fillna(0)
test['Waterproof']=test['Waterproof'].fillna(0)

# %%
#weight capacity
train_input['Weight Capacity (kg)'].mode()
# Out:
# 0    5.0
# Name: Weight Capacity (kg), dtype: float64

# %%
train_input['Weight Capacity (kg)'].describe()
# Out:
# count    299862.000000
# mean         18.029994
# std           6.966914
# min           5.000000
# 25%          12.097867
# 50%          18.068614
# 75%          24.002375
# max          30.000000
# Name: Weight Capacity (kg), dtype: float64

# %%
# 중앙값으로 대체
train_input['Weight Capacity (kg)']=train_input['Weight Capacity (kg)'].fillna(18.07)
test['Weight Capacity (kg)']=test['Weight Capacity (kg)'].fillna(18.07)

# %% [markdown]
# **범주형 변수 결측값 처리**

# %%
#범주형 변수 결측값 처리
categorical=['Brand', 'Style', 'Material', 'Color']
for cat in categorical:
  train_input[cat]=train_input[cat].fillna(train_input[cat].mode()[0])
  test[cat]=test[cat].fillna(test[cat].mode()[0])

# %%
#결측치 처리 확인
train_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Brand                 300000 non-null  object
#  1   Material              300000 non-null  object
#  2   Size                  300000 non-null  float64
#  3   Compartments          300000 non-null  float64
#  4   Laptop Compartment    300000 non-null  float64
#  5   Waterproof            300000 non-null  float64
#  6   Style                 300000 non-null  object
#  7   Color                 300000 non-null  object
#  8   Weight Capacity (kg)  300000 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 20.6+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Brand                 200000 non-null  object
#  1   Material              200000 non-null  object
#  2   Size                  200000 non-null  float64
#  3   Compartments          200000 non-null  float64
#  4   Laptop Compartment    200000 non-null  float64
#  5   Waterproof            200000 non-null  float64
#  6   Style                 200000 non-null  object
#  7   Color                 200000 non-null  object
#  8   Weight Capacity (kg)  200000 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 13.7+ MB

# %% [markdown]
# **범주형 변수 변환**

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#원핫인코딩
cols = [ "Brand", "Style", "Material", "Color"]
train_input = pd.get_dummies(train_input, columns=cols, drop_first=True).astype(int)
test = pd.get_dummies(test, columns=cols, drop_first=True).astype(int)

# %%
train_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Size                  300000 non-null  int64
#  1   Compartments          300000 non-null  int64
#  2   Laptop Compartment    300000 non-null  int64
#  3   Waterproof            300000 non-null  int64
#  4   Weight Capacity (kg)  300000 non-null  int64
#  5   Brand_Jansport        300000 non-null  int64
#  6   Brand_Nike            300000 non-null  int64
#  7   Brand_Puma            300000 non-null  int64
#  8   Brand_Under Armour    300000 non-null  int64
#  9   Style_Messenger       300000 non-null  int64
#  10  Style_Tote            300000 non-null  int64
#  11  Material_Leather      300000 non-null  int64
#  12  Material_Nylon        300000 non-null  int64
#  13  Material_Polyester    300000 non-null  int64
#  14  Color_Blue            300000 non-null  int64
#  15  Color_Gray            300000 non-null  int64
#  16  Color_Green           300000 non-null  int64
#  17  Color_Pink            300000 non-null  int64
#  18  Color_Red             300000 non-null  int64
# dtypes: int64(19)
# memory usage: 43.5 MB
